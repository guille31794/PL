# %% [markdown]
# # Practice 1: Syntax-directed translation
#
# Design a grammar using a bottom - up translator that accepts the following input in C language:
#     - Assignment statement
#     - Conditional instructions (if - else)
#     - Comparison operators (==, <=, >=, !=)
#     - Logic operators (AND, OR, NOT)
#     - Arithmetic operators (+, - , *, / and unary operator (-))
#     - Variables, numerical constants and vectors

# %%
from sly import Lexer, Parser
import sys

tabla={}
banderaIF = False
banderaExpr = False

class NodoPrint():
    def P(a):
        global banderaIF, banderaExpr
        if banderaIF == False or (banderaIF == True and banderaExpr == True):
            if a in tabla:
                print(tabla[a])
            else:
                print("Syntax error: ID '%c' isnt in table." %a) 

class NodoID():
    def P(a,b):
        global banderaIF, banderaExpr
        if banderaIF == False or (banderaIF == True and banderaExpr == True):
            tabla[a]=b
            print(tabla)

class NodoGen():
    def P(a):
        return a    
    
class NodoMenor():
    def P(a,b):
        return a<b

class NodoMayor():
    def P(a,b):
        return a>b
    
class NodoMenorIg():
    def P(a,b):
        return a<=b

class NodoMayorIg():
    def P(a,b):
        return a>=b

class NodoIg():
    def P(a,b):
        return a==b
    
class NodoAnd():
    def P(a,b):
        return a&b

class NodoOr():
    def P(a,b):
        return a|b

class NodoNot():
    def P(a):
        return ~a
    
class NodoSum():
    def P(a,b):
        return a+b
    
class NodoResta():
    def P(a,b):
        return a-b
    
class NodoMul():
    def P(a,b):
        return a*b
    
class NodoDiv():
    def P(a,b):
        return a/b
    
class NodoRU():
    def P(a):
        return -a
    
class NodoTabla():
    def P(a):
        return tabla[a]

class CalcLexer(Lexer):
    tokens = {DIGIT, ID, LESEQ, BIGEQ, EQ, PRINTF, PGENERIC, IF , ELSE}
    ignore = ' \t'
    DIGIT = r'[0-9]+'
    PRINTF = r'printf'
    PGENERIC = r'%d'
    IF = r'if'
    ELSE = r'else'
    ID = r'[a-zA-Z][a-zA-Z0-9]*'
    
    LESEQ = r'<='
    BIGEQ = r'>='
    EQ = r'=='
    
    literals = {'+', '-', '*', '/', '(', ')', '<', '>', '=', ';', '|', '&', '~', ',', '"', '{', '}'}
    
    @_(r'[0-9]+')
    def DIGIT(self, f):
        f.value=int(f.value)
        return f
    
    def ID(self, f):
        f.value = str(f.value)
        return f
    
    def error(self, t):
        print('Bad character %r' % t.value[0])
        sys.exit(0)    
    
class CalcParser(Parser):
    tokens=CalcLexer.tokens
    def __init__(self):
        self.names={}
    
    @_('')
    def entrada(self, p):
        pass
    
    @_('entrada datos')
    def entrada(self,p):
        pass
    
    @_('entrada sentenciaIF')
    def entrada(self, p):
        pass
    
    @_('IF "(" expr emptyIF ")" "{" entrada "}"')
    def sentenciaIF(self, p):
        global banderaIF
        banderaIF = False
        pass

    @_('IF "(" expr emptyIF ")" "{" entrada "}" ELSE emptyELSE "{" entrada "}" ')
    def sentenciaIF(self, p):
        global banderaIF
        banderaIF = False
        pass
    
    @_('')
    def emptyIF(self, p):
        global banderaIF, banderaExpr
        banderaIF = True
        banderaExpr = p[-1]
        pass
    
    @_('')
    def emptyELSE(self, p):
        global banderaExpr
        if banderaExpr == True:
            banderaExpr = False
        else:
            banderaExpr = True
        pass
    
    @_('PRINTF "(" """ PGENERIC mas ID ")" ";"')
    def datos(self, p):
            NodoPrint.P(p.ID)
            
    @_('""" ","')
    def mas(self,p):
        pass
    
    @_('PGENERIC mas ID ","')
    def mas(self ,p):
        NodoPrint.P(p.ID)        
        
    @_('ID "=" expr ";"')
    def datos(self, p):
        NodoID.P(p.ID, p.expr)
        
    @_('expr "<" comp')
    def expr(self, p):
        return NodoMenor.P(p.expr, p.comp)
    
    @_('expr ">" comp')
    def expr(self, p):
        return NodeoMayor.P(p.expr, p.comp)
    
    @_('expr LESEQ comp')
    def expr(self, p):
        return NodoMenorIg.P(p.expr, p.comp)
    
    @_('expr BIGEQ comp')
    def expr(self, p):
        return NodeoMayorIg.P(p.expr, p.comp)
    
    @_('expr EQ comp')
    def expr(self, p):
        return NodoIg.P(p.expr, p.comp)
    
    @_('expr "&" comp')
    def expr(self, p):
        return NodoAnd.P(p.expr, p.comp)
    
    @_('expr "|" comp')
    def expr(self, p):
        return NodoOr.P(p.expr, p.comp)
    
    @_('"~" expr')
    def expr(self, p):
        return NodoNot.P(p.expr)
    
    @_('comp')
    def expr(self, p):
        return NodoGen.P(p.comp)
    
    @_('comp "+" sum')
    def comp(self, p):
        return NodoSum.P(p.comp, p.sum)
    
    @_('comp "-" sum')
    def comp(self, p):
        return NodoResta.P(p.comp, p.sum)
    
    @_('sum')
    def comp(self, p):
        return NodoGen.P(p.sum)
    
    @_('sum "*" fact')
    def sum(self, p):
        return NodoMul.P(p.sum, p.fact)
    
    @_('sum "/" fact')
    def sum(self, p):
        return NodoDiv.P(p.sum, p.fact)
    
    @_('fact')
    def sum(self, p):
        return NodoGen.P(p.fact)
    
    @_('"-" fact')
    def fact(self, p):
        return NodoRU.P(p.fact)
    
    @_('ID')
    def fact(self, p):
        return NodoTabla.P(p.ID)
    
    @_('"(" expr ")"')
    def fact(self, p):
        return NodoGen.P(p.expr)
    
    @_('DIGIT')
    def fact(self, p):
        return NodoGen.P(p.DIGIT)

if __name__=='__main__':
    lexer=CalcLexer()
    parser=CalcParser()
    while True:
        try:
            text=input('one expression plix > ')
        except EOFError:
            break
        if text:
            parser.parse(lexer.tokenize(text))
# Out:
# WARNING: 7 shift/reduce conflicts
# one expression plix > x=3;
# {'x': 3}
# one expression plix > if(x==3){p=0;}
# {'x': 3, 'p': 0}
# one expression plix > if(x==3){p=0;}else{op=12;}
# {'x': 3, 'p': 0}
# one expression plix > if(x==2){p=0;}else{op=12;}
# {'x': 3, 'p': 0, 'op': 12}
# one expression plix > if(x==2){p=1;}else{op=12;}
# {'x': 3, 'p': 0, 'op': 12}
# one expression plix > if(x==3){p=0;}else{op=11;}
# {'x': 3, 'p': 0, 'op': 12}
# one expression plix > if(x==2){p=0;}else{op=11;}
# {'x': 3, 'p': 0, 'op': 11}
# one expression plix > if(x==2){p=1;}else{op=11;}
# {'x': 3, 'p': 0, 'op': 11}

# %% [markdown]
# #####  José Luis Cumbrera Sánchez, Teodoro Martínez Márquez
