# %% [markdown]
# # Practice 2: Writing a Parser using SLY
#
# From previous practice, add the following items:
#     - Parenthesis
#     - Relational operators (<, >, <= , >=, !=)
#     - printf instruction
