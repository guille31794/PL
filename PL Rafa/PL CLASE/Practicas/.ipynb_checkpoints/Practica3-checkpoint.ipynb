# %% [markdown]
# # Practice 3: Translator using AST
#
# Starting from the developed grammar in practice 1, add the follow points:
#     - printf instruction
#     - AST for arithmetics, relational and logics calculus
#
# At the end, the result will be shown if printf instruction exits.

# %%
# calclex.py
####################################################################
#   TRABAJO REALIZADO POR JUAN RUIZ BONALD,RAFAEL ROMAN AGUILAR #
###################################################################



from sly import Lexer,Parser

class PracLexer(Lexer):
    # Set of token names.   This is always required
    tokens = { NUMBER, ID, WHILE, IF, ELSE, PRINT,
               PLUS, MINUS, TIMES, DIVIDE, ASSIGN,
               EQ, LT, LE, GT, GE, NE, AND, NOT}


    literals = { '(', ')', '{', '}', ';' }

    # String containing ignored characters
    ignore = ' \t'

    # Regular expression rules for tokens
    PLUS    = r'\+'
    MINUS   = r'-'
    TIMES   = r'\*'
    DIVIDE  = r'/'
    EQ      = r'=='
    ASSIGN  = r'='
    LE      = r'<='
    LT      = r'<'
    GE      = r'>='
    GT      = r'>'
    NE      = r'!='
    AND     = r'&&'
    NOT     = r'!'

    @_(r'\d+')
    def NUMBER(self, t):
        t.value = int(t.value)
        return t

    # Identifiers and keywords
    ID = r'[a-zA-Z_][a-zA-Z0-9_]*'
    ID['if'] = IF
    ID['else'] = ELSE
    ID['while'] = WHILE
    ID['print'] = PRINT

    ignore_comment = r'\#.*'

    # Line number tracking
    @_(r'\n+')
    def ignore_newline(self, t):
        self.lineno += t.value.count('\n')

    def error(self, t):
        print('Line %d: Bad character %r' % (self.lineno, t.value[0]))
        self.index += 1

        
class PracParser(Parser):
    tokens = PracLexer().tokens
    
    def __init__(self):
        self.names = { }
        
    @_('entrada instruccion')
    def entrada(self,p):
        print(p.instruccion)

    @_(' ')
    def entrada(self, p):
        print(" ")

    @_('expr PLUS sum')
    def expr(self, p):
        return p.expr + p.sum
    
    @_('expr MINUS sum')
    def expr(self, p):
        return p.expr - p.sum

    @_('sum')
    def expr(self, p):
        return p.sum

    @_('sum TIMES factor')
    def sum(self, p):
        return p.sum * p.factor
    
    @_('sum DIVIDE factor')
    def sum(self, p):
        return p.sum / p.factor

    @_('factor EQ factor')
    def sum(self,p):
        return int(p.factor0 == p.factor1)
    
    @_('factor NE factor')
    def sum(self,p):
        return int(p.factor0 != p.factor1)
    
    @_('factor GE factor')
    def sum(self,p):
        return int(p.factor0 >= p.factor1)
    
    @_('factor LE factor')
    def sum(self,p):
        return int(p.factor0 <= p.factor1)
    
    @_('factor AND factor')   
    def sum(self,p):
        return int(p.factor0 & p.factor1)
    
    @_('factor GT factor')   
    def sum(self,p):
        return int(p.factor0 > p.factor1)
    
    @_('factor LT factor')   
    def sum(self,p):
        return int(p.factor0 < p.factor1)
    
    #@_('factor OR factor')   
    #def sum(self,p):
    #    return int(p.factor0 | p.factor1)
    
    @_('NOT factor')   
    def sum(self,p):
        return int(~p.factor)
    
    @_('factor')
    def sum(self, p):
        return p.factor

    @_('"-" factor')
    def factor(self, p):
        return -p.factor

    @_('NUMBER')
    def factor(self, p):
        return p.NUMBER

    @_('"(" expr ")"')
    def factor(self, p):
        return p.expr
   
    @_('asignacion')
    def instruccion(self,p):
        return p.asignacion
    
    @_('condicional')
    def instruccion(self,p):
        return p.condicional
    
    @_('ID ASSIGN asignacion_ ";"')
    def asignacion(self,p):
        return p.asignacion_
         
    @_('IF')
    def condicional(self,p):
        print("CONDICIONAL")
    
    @_('ID')
    def asignacion_(self,p):
        return p.ID
    
    @_('expr')
    def asignacion_(self,p):
        return p.expr
    

    
if __name__ == '__main__':
    lexer = PracLexer()
    parser = PracParser()
    while True:
        try:
            text = input('asignacion ');
        except EOFError:
            break
        if text:
            parser.parse(lexer.tokenize(text))
# Out:
# WARNING: Token 'WHILE' defined, but not used
# WARNING: Token 'PRINT' defined, but not used
# WARNING: Token 'ELSE' defined, but not used
# WARNING: There are 3 unused tokens
# asignacion x = 5;
#
# 5
# asignacion x = (1==1);
#
# 1
# asignacion x = 1==1;
#
# 1
# asignacion x = (1>2);
#
# 0
# asignacion x = (1<=2);
#
# 1
# asignacion x = 1<=2;
#
# 1

# %%
x = 4;
