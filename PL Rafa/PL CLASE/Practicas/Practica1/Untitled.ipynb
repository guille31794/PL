# %%
@_('entrada expr ";"')
def entrada(self, p):
print(p.expr)
@_(' ')
def entrada(self, p):
print(" ")
@_('expr "+" sum')
def expr(self, p):
return p.expr + p.sum
@_('sum')
def expr(self, p):
return p.sum
@_('sum "*" factor')
def sum(self, p):
return p.sum * p.factor
