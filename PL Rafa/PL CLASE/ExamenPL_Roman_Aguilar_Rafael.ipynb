# %%
# Ejercicio 1: diseñe una gramatica...
Entrada -> Linea Entrada 
Entrada -> epsilon

Linea -> ID EQUAL Asign ';'
Linea -> PRINT Asign ';'

Asign -> Bool Asign
Asign -> '('Asign')'Asign
Asign -> AND Asign
Asign -> NOT Asign
Asign -> OR Asign
Asign -> epsilon
Asign -> ID Asign

Bool -> FALSE | TRUE


ID = [a-zA-Z0-9_][a-zA-Z0-9_]*
EQUAL = '.='
literals = ';','(',')'

ID['and'] = AND
ID['or'] = OR
ID['not'] = NOT
ID['true'] = TRUE
ID['false'] = FALSE
ID['print'] = PRINT
