# %% [markdown]
# # Exercise 1
#
# Design translation scheme (offset parameters Pascal style. That is, the parameters are put on the stack from left to right). Calculate the first and follow sets. Develop this grammar using SLY.
#
# Grammar:
# Def   -> ID ‘(‘ Tipo ID Resto’)’ <br>
# Resto -> ‘,’ Tipo ID Resto <br>
# Resto -> epsilon <br>
# Tipo -> INT  <br>
# Tipo -> CHAR  <br>
# Tipo -> FLOAT <br>
#  <br>
# Example:  <br>
#  <br>
# Input : f(int a, float b, char c) <br>
# Output: Offset de c = 4 <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Offset de b = 4 + sizeof(char)  <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Offset de a = 4 + sizeof(char) + sizeof(float) <br>

# %%
from sly import Lexer,Parser

class LexerSem4(Lexer):
    
    #tokens
    tokens = {ID,INT,FLOAT,CHAR}
    ID = r'[a-zA-Z_][a-zA-Z0-9_]*'
    ID['int'] = INT
    ID['float'] = FLOAT
    ID['char'] = CHAR
    
    #literals
    literals = {',','(',')'}

    #ignore
    ignore = ' \t'
    
    
class ParserSem4(Parser):
    tokens = LexerSem4().tokens
    
    def __init__(self):
        self.names = {}
                
    @_('ID "(" Tipo ID Resto ")"')
    def DEF(self,p):
        print("Offset de ",p.ID1,"=",p.Resto)
        
    @_('"," Tipo ID Resto')
    def Resto(self,p):
        print("Offset de ",p.ID,"=",p.Resto)
        return p.Resto + ' + ' + p.Tipo
    
    @_(' ')
    def Resto(self,p):
        return '4'
    
    @_('INT')
    def Tipo(self,p):
        return "sizeof(int)"
    
    @_('FLOAT')
    def Tipo(self,p):
        return "sizeof(float)"
    
    @_('CHAR')
    def Tipo(self,p):
        return "sizeof(char)"        
    
if __name__ == '__main__':
    lexer = LexerSem4()
    parser = ParserSem4()
    while True:
        try:
            text = input('INPUT: ');
        except EOFError:
            break
        if text:
            parser.parse(lexer.tokenize(text))
