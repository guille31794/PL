# %% [markdown]
# # Practice 3: Writing a Parser using SLY
#
# Starting from the developed grammar in practice 2, add the follow points:
#     - printf instruction
#     - integer variables declarations
#
# At the end, the result will be shown if printf instruction exits.
